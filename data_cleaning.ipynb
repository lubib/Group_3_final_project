# %%
# Importing dependencies
import pandas as pd

# %%
# Setting filepaths for raw data
rawpath_population = "raw_data/world_population.csv"
rawpath_gdp_per_capita = "raw_data/gdp_per_capita.csv"
rawpath_hdi = "raw_data/human-development-index-hdi-2014.csv"
rawpath_gii = "raw_data/Gender Inequality Index (GII).csv"
rawpath_cpi = "raw_data/Corruption_Perceptions_Index_CPI.csv"
rawpath_winter_medals = "raw_data/2014_winter_medal_count.csv"
rawpath_summer_medals = "raw_data/2012_summer_medal_count.csv"

# %%
# Reading in csv files as DataFrames
population_df = pd.read_csv(rawpath_population)
gdp_per_capita_df = pd.read_csv(rawpath_gdp_per_capita)
hdi_df = pd.read_csv(rawpath_hdi)
gii_df = pd.read_csv(rawpath_gii, encoding = "ISO-8859-1", engine='python', skipfooter=1)
cpi_df = pd.read_csv(rawpath_cpi)
winter_medals_df = pd.read_csv(rawpath_winter_medals)
summer_medals_df = pd.read_csv(rawpath_summer_medals)

# %%
# Setting commonly recognized names for the population df; this will make it easier to later join this dataset with others
population_df["Country Name"][21] = "Bahamas"
population_df["Country Name"][45] = "Cape Verde"
population_df["Country Name"][41] = "Democratic Republic of the Congo"
population_df["Country Name"][42] = "Congo Republic"
population_df["Country Name"][65] = "Egypt"
population_df["Country Name"][84] = "Gambia"
population_df["Country Name"][94] = "Hong Kong"
population_df["Country Name"][110] = "Iran"
population_df["Country Name"][124] = "South Korea"
population_df["Country Name"][191] = "North Korea"
population_df["Country Name"][120] = "Kyrgyzstan"
population_df["Country Name"][127] = "Lao People's Democratic Republic"
population_df["Country Name"][77] = "Micronesia (Federated States of)"
population_df["Country Name"][200] = "Russia"
population_df["Country Name"][123] = "Saint Kitts and Nevis"
population_df["Country Name"][131] = "Saint Lucia"
population_df["Country Name"][219] = "Slovakia"
population_df["Country Name"][222] = "Swaziland"
population_df["Country Name"][252] = "Venezuela"
population_df["Country Name"][260] = "Yemen"
population_df["Country Name"][251] = "Saint Vincent and the Grenadines"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Setting commonly recognized names for the gdp_per_capita df; this will make it easier to later join this dataset with others
gdp_per_capita_df["Country Name"][21] = "Bahamas"
gdp_per_capita_df["Country Name"][45] = "Cape Verde"
gdp_per_capita_df["Country Name"][41] = "Democratic Republic of the Congo"
gdp_per_capita_df["Country Name"][42] = "Congo Republic"
gdp_per_capita_df["Country Name"][65] = "Egypt"
gdp_per_capita_df["Country Name"][84] = "Gambia"
gdp_per_capita_df["Country Name"][94] = "Hong Kong"
gdp_per_capita_df["Country Name"][110] = "Iran"
gdp_per_capita_df["Country Name"][124] = "South Korea"
gdp_per_capita_df["Country Name"][191] = "North Korea"
gdp_per_capita_df["Country Name"][120] = "Kyrgyzstan"
gdp_per_capita_df["Country Name"][127] = "Lao People's Democratic Republic"
gdp_per_capita_df["Country Name"][77] = "Micronesia (Federated States of)"
gdp_per_capita_df["Country Name"][200] = "Russia"
gdp_per_capita_df["Country Name"][123] = "Saint Kitts and Nevis"
gdp_per_capita_df["Country Name"][131] = "Saint Lucia"
gdp_per_capita_df["Country Name"][219] = "Slovakia"
gdp_per_capita_df["Country Name"][222] = "Swaziland"
gdp_per_capita_df["Country Name"][252] = "Venezuela"
gdp_per_capita_df["Country Name"][260] = "Yemen"
gdp_per_capita_df["Country Name"][251] = "Saint Vincent and the Grenadines"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Setting population for Eritria to last known value
population_df["2014"][67] = population_df["2011"][67]
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Setting commonly recognized names for the HDI df; this will make it easier to later join this dataset with others
hdi_df["Location"][11] = "Hong Kong"
hdi_df["Location"][16] = "South Korea"
hdi_df["Location"][49] = "Russia"
hdi_df["Location"][68] = "Iran"
hdi_df["Location"][70] = "Venezuela"
hdi_df["Location"][81] = "North Macedonia"
hdi_df["Location"][106] = "Moldova"
hdi_df["Location"][117] = "Vietnam"
hdi_df["Location"][118] = "Bolivia"
hdi_df["Location"][121] = "Cape Verde"
hdi_df["Location"][135] = "Congo Republic"
hdi_df["Location"][150] = "Tanzania"
hdi_df["Location"][171] = "Cote d'Ivoire"
hdi_df["Location"][175] = "Democratic Republic of the Congo"
hdi_df["Location"][196] = "North Korea"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Testing to see that country names match in hdi_df & population_df
test_df1 = pd.merge(hdi_df, population_df, left_on = 'Location', right_on = 'Country Name', how = 'left')
test_df1[test_df1["Country Name"].isnull() == True]
# Out:
#       Rank                                           Location  \
# 112  113.0                                Palestine, State of
# 190    NaN                              Low human development
# 191    NaN                          Least developed countries
# 193    NaN                           Medium human development
# 194    NaN                               Developing countries
# 195    NaN                     Small island developing states
# 197    NaN                                        Arab States
# 199    NaN                            Europe and Central Asia
# 200    NaN                          East Asia and the Pacific
# 201    NaN                    Latin America and the Caribbean
# 202    NaN                             High human development
# 203    NaN  Organisation for Economic Co-operation and Dev...
# 204    NaN                        Very high human development
#
#      Human Development Index (HDI)   Life expectancy at birth  \
# ...

# %%
# Removing space character at the front of each country name in GII df
gii_df["Country"] = gii_df["Country"].str[1:]

# %%
# Setting commonly recognized names for the GII df; this will make it easier to later join this dataset with others 
gii_df["Country"][17] = "Bolivia"
gii_df["Country"][32] = "Congo Republic"
gii_df["Country"][33] = "Democratic Republic of the Congo"
gii_df["Country"][39] = "Cote d'Ivoire"
gii_df["Country"][64] = "Iran"
gii_df["Country"][74] = "South Korea"
gii_df["Country"][93] = "Moldova"
gii_df["Country"][117] = "Russia"
gii_df["Country"][139] = "Tanzania"
gii_df["Country"][141] = "North Macedonia"
gii_df["Country"][155] = "Venezuela"
gii_df["Country"][156] = "Vietnam"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Testing to see that country names match in gii_df & population_df
test_df1 = pd.merge(gii_df, population_df, left_on = 'Country', right_on = 'Country Name', how = 'left')
test_df1[test_df1["Country Name"].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [HDI Rank (2015), Country, 1995_x, 2000_x, 2005_x, 2010_x, 2011_x, 2012_x, 2013_x, 2014_x, 2015_x, Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995_y, 1996, 1997, 1998, 1999, 2000_y, 2001, 2002, 2003, 2004, 2005_y, 2006, 2007, 2008, 2009, 2010_y, 2011_y, 2012_y, 2013_y, 2014_y, 2015_y, 2016, 2017, 2018, 2019, 2020]
# Index: []
#
# [0 rows x 76 columns]

# %%
# Setting commonly recognized names for the CPI df; this will make it easier to later join this dataset with others 
cpi_df["Country/Territory"][43] = "South Korea"
cpi_df["Country/Territory"][64] = "North Macedonia"
cpi_df["Country/Territory"][114] = "Cote d'Ivoire"
cpi_df["Country/Territory"][147] = "Lao People's Democratic Republic"
cpi_df["Country/Territory"][159] = "Syrian Arab Republic"
cpi_df["Country/Territory"][173] = "North Korea"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Testing to see that country names match in cpi_df & population_df
test_df1 = pd.merge(cpi_df, population_df, left_on = 'Country/Territory', right_on = 'Country Name', how = 'left')
test_df1[test_df1["Country Name"].isnull() == True]
# Out:
#     Country Rank Country/Territory Country Code_x Region  CPI 2014  \
# 36            36            Taiwan            TWN     AP        61
#
#     Number of Surveys Used  Std Error  Min  Max  90% Lower CI  ...  2011  \
# 36                       7       4.17   48   79            54  ...   NaN
#
#     2012  2013  2014  2015  2016  2017  2018  2019  2020
# 36   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 88 columns]

# %%
# Removing empty space character at the end of each country name
winter_medals_df["NOC"] = winter_medals_df["NOC"].str[:-1]
summer_medals_df["NOC"] = summer_medals_df["NOC"].str[:-1]

# %%
# Setting commonly recognized names for the winter medals df; this will make it easier to later join this dataset with others 
winter_medals_df["NOC"][18] = "United Kingdom"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_df1 = pd.merge(winter_medals_df, population_df, left_on = 'NOC', right_on = 'Country Name', how = 'left')
test_df1[test_df1["Country Name"].isnull() == True]
# Out:
# Empty DataFrame
# Columns: [Rank, NOC, Unnamed: 2, Gold, Silver, Bronze, Total, Country Name, Country Code, Indicator Name, Indicator Code, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# Index: []
#
# [0 rows x 72 columns]

# %%
# Setting commonly recognized names for the winter medals df; this will make it easier to later join this dataset with others 
summer_medals_df["NOC"][2] = "United Kingdom"
# Out:
# C:\Users\Seva\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test_df1 = pd.merge(summer_medals_df, population_df, left_on = 'NOC', right_on = 'Country Name', how = 'left')
test_df1[test_df1["Country Name"].isnull() == True]
# Out:
#     Rank             NOC Unnamed: 2  Gold  Silver  Bronze  Total Country Name  \
# 47  48.0  Chinese Taipei        TPE     1       0       1      2          NaN
#
#    Country Code Indicator Name  ... 2011  2012  2013  2014  2015  2016  2017  \
# 47          NaN            NaN  ...  NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#     2018  2019  2020
# 47   NaN   NaN   NaN
#
# [1 rows x 72 columns]

# %%
# Setting filepaths for clean data
cleanpath_population = "clean_data/world_population.csv"
cleanpath_gdp_per_capita = "clean_data/gdp_per_capita.csv"
cleanpath_hdi = "clean_data/human_development_index_2014.csv"
cleanpath_gii = "clean_data/gender_inequality_index.csv"
cleanpath_cpi = "clean_data/corruption_perceptions_index.csv"
cleanpath_winter_medals = "clean_data/2014_winter_medal_count.csv"
cleanpath_summer_medals = "clean_data/2012_summer_medal_count.csv"

# %%
# Writing cleaned DataFrames to new csv files
population_df.to_csv(cleanpath_population,index=False)
gdp_per_capita_df.to_csv(cleanpath_gdp_per_capita,index=False)
hdi_df.to_csv(cleanpath_hdi,index=False)
gii_df.to_csv(cleanpath_gii,index=False)
cpi_df.to_csv(cleanpath_cpi,index=False)
winter_medals_df.to_csv(cleanpath_winter_medals,index=False)
summer_medals_df.to_csv(cleanpath_summer_medals,index=False)
